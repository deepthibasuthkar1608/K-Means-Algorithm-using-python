# %% [markdown]
# <a href="https://colab.research.google.com/github/deepthibasuthkar1608/K-Means-Algorithm-using-python/blob/main/Wholesale_customers_data.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
from sklearn.cluster import KMeans
from sklearn.preprocessing import StandardScaler

# Load the CSV data file
path= "/content/Wholesale_customers_data[1].csv"
data = pd.read_csv(path)

# Extract numerical data
X = data.iloc[:, 1:].values  # Assuming the numerical data starts from the second column

# Preprocessing: Standardize the features
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# Initialize KMeans
kmeans = KMeans(n_clusters=3, n_init=10, random_state=42)


# Fit KMeans
kmeans.fit(X_scaled)

# Get cluster labels
labels = kmeans.labels_

# Get cluster centroids
centroids = kmeans.cluster_centers_

# Add cluster labels to the original dataframe
data['Cluster'] = labels

# Analyze the results
cluster_counts = data['Cluster'].value_counts()
print("Cluster Counts:")
print(cluster_counts)
print("\nCluster Centroids:")
print(centroids)
# Out:
# Cluster Counts:
# Cluster
# 0    295
# 1    116
# 2     29
# Name: count, dtype: int64
#
# Cluster Centroids:
# [[ 0.59066829  0.00929508 -0.18187563 -0.19330619 -0.04708694 -0.19476619
#   -0.07213098]
#  [-1.51603847 -0.08697667 -0.17028333 -0.17261269  0.08265557 -0.17061006
#   -0.10634697]
#  [ 0.05563165  0.25335327  2.53124752  2.65684135  0.14836558  2.66368248
#    1.15913404]]

# %%
import pandas as pd
from sklearn.cluster import KMeans
import matplotlib.pyplot as plt
from sklearn.preprocessing import StandardScaler

# Load the CSV data into a DataFrame
path= "/content/Wholesale_customers_data[1].csv"
data = pd.read_csv(path)

# Select the features for clustering
X = data[['Fresh', 'Milk', 'Grocery', 'Frozen', 'Detergents_Paper', 'Delicassen']]

# Standardize the features
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# Choose the number of clusters (k)
k = 8

# Perform K-means clustering
kmeans = KMeans(n_clusters=k, random_state=42)
kmeans.fit(X_scaled)

# Add the cluster labels to the DataFrame
data['cluster'] = kmeans.labels_

# Plot the clusters
plt.figure(figsize=(12, 8))
plt.scatter(data['Channel'], data['Region'], c=data['cluster'], cmap='viridis')
plt.xlabel('Channel')
plt.ylabel('Region')
plt.title('K-means Clustering of Wholesale Customers with 8 Clusters')
plt.show()
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(

# %%
import pandas as pd
from sklearn.cluster import KMeans
import matplotlib.pyplot as plt
from sklearn.preprocessing import StandardScaler

# Load the CSV data into a DataFrame
path= "/content/Wholesale_customers_data[1].csv"
data = pd.read_csv(path)

# Select the features for clustering
X = data[['Channel','Region', 'Fresh', 'Milk', 'Grocery', 'Frozen', 'Detergents_Paper', 'Delicassen']]

# Standardize the features
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# Choose the number of clusters (k)
k = 8

# Perform K-means clustering
kmeans = KMeans(n_clusters=k, random_state=42)
kmeans.fit(X_scaled)

# Add the cluster labels to the DataFrame
data['cluster'] = kmeans.labels_

# Plot the clusters
plt.figure(figsize=(12, 8))
plt.scatter(data['Channel'], data['Region'], c=data['cluster'], cmap='viridis', s=data['Fresh'], label='Fresh')
plt.scatter(data['Channel'], data['Region'], c=data['cluster'], cmap='viridis', s=data['Milk'], label='Milk')
plt.scatter(data['Channel'], data['Region'], c=data['cluster'], cmap='viridis', s=data['Grocery'], label='Grocery')
plt.scatter(data['Channel'], data['Region'], c=data['cluster'], cmap='viridis', s=data['Frozen'], label='Frozen')
plt.scatter(data['Channel'], data['Region'], c=data['cluster'], cmap='viridis', s=data['Detergents_Paper'], label='Detergents_Paper')
plt.scatter(data['Channel'], data['Region'], c=data['cluster'], cmap='viridis', s=data['Delicassen'], label='Delicassen')
plt.xlabel('Region')
plt.ylabel('Channel')
plt.title('K-means Clustering of Wholesale Customers with 8 Clusters')
plt.legend()
plt.show()
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.datasets import make_blobs
X,y = make_blobs(n_samples = 500,n_features = 2,centers = 3,random_state = 23)

fig = plt.figure(0)
plt.grid(True)
plt.scatter(X[:,0],X[:,1])
plt.show()

# %%
import pandas as pd
from sklearn.cluster import KMeans
import matplotlib.pyplot as plt
from sklearn.preprocessing import StandardScaler

# Load the CSV data into a DataFrame
path= "/content/Wholesale_customers_data[1].csv"
data = pd.read_csv(path)

# Select the features for clustering
X = data[['Fresh', 'Milk', 'Grocery', 'Frozen', 'Detergents_Paper', 'Delicassen']]

# Standardize the features
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# Choose the number of clusters (k)
k = 8

# Perform K-means clustering
kmeans = KMeans(n_clusters=k, random_state=42)
kmeans.fit(X_scaled)

# Add the cluster labels to the DataFrame
data['cluster'] = kmeans.labels_

# Plot the clusters
plt.figure(figsize=(12, 8))
plt.scatter(data['Channel'], data['Region'], c=data['cluster'], cmap='viridis', s=data['Fresh'], label='Fresh')
plt.scatter(data['Channel'], data['Region'], c=data['cluster'], cmap='viridis', s=data['Milk'], label='Milk')
plt.scatter(data['Channel'], data['Region'], c=data['cluster'], cmap='viridis', s=data['Grocery'], label='Grocery')
plt.scatter(data['Channel'], data['Region'], c=data['cluster'], cmap='viridis', s=data['Frozen'], label='Frozen')
plt.scatter(data['Channel'], data['Region'], c=data['cluster'], cmap='viridis', s=data['Detergents_Paper'], label='Detergents_Paper')
plt.scatter(data['Channel'], data['Region'], c=data['cluster'], cmap='viridis', s=data['Delicassen'], label='Delicassen')
plt.xlabel('Channel')
plt.ylabel('Region')
plt.title('K-means Clustering of Wholesale Customers with 8 Clusters')
plt.legend()
plt.show()
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(

# %%
import numpy as np
import pandas as pd
from sklearn.cluster import KMeans
import matplotlib.pyplot as plt

# Load the CSV data into a DataFrame
path= "/content/Wholesale_customers_data[1].csv"
data = pd.read_csv(path)

# Select the features for clustering
X = data[['Fresh', 'Milk', 'Grocery', 'Frozen', 'Detergents_Paper', 'Delicassen']].values

# Data preprocessing (standardization)
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# Choose the number of clusters (k)
k = 3

# Perform K-means clustering
kmeans = KMeans(n_clusters=k, random_state=42)
y_predict = kmeans.fit_predict(X_scaled)

# Add the cluster labels to the DataFrame
data['cluster'] = y_predict

# Visualize the clusters
plt.figure(figsize=(12, 8))
plt.scatter(X_scaled[:, 0], X_scaled[:, 1], c=y_predict, cmap='viridis')
plt.scatter(kmeans.cluster_centers_[:, 0], kmeans.cluster_centers_[:, 1], s=300, c='red', label='Centroids')
plt.xlabel('Standardized Feature 1')
plt.ylabel('Standardized Feature 2')
plt.title('K-means Clustering of Wholesale Customers')
plt.legend()
plt.show()
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(

# %%
import numpy as np
import pandas as pd
from sklearn.cluster import KMeans
import matplotlib.pyplot as plt

# Load the CSV data into a DataFrame
path= "/content/Wholesale_customers_data[1].csv"
data = pd.read_csv(path)

# Select the features for clustering
X = data[['Fresh', 'Milk', 'Grocery', 'Frozen', 'Detergents_Paper', 'Delicassen']].values

# Data preprocessing (standardization)
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# Choose the number of clusters (k)
k = 5

# Perform K-means clustering
kmeans = KMeans(n_clusters=k, random_state=42)
y_predict = kmeans.fit_predict(X_scaled)

# Add the cluster labels to the DataFrame
data['cluster'] = y_predict

# Get the cluster centroids
centroids = kmeans.cluster_centers_

# Print the centroids
print("Cluster centroids:")
for i, centroid in enumerate(centroids):
    print(f"Cluster {i+1}: {centroid}")

# Visualize the clusters
plt.figure(figsize=(12, 8))
plt.scatter(X_scaled[:, 0], X_scaled[:, 1], c=y_predict, cmap='viridis')
plt.scatter(centroids[:, 0], centroids[:, 1], s=300, c='red', label='Centroids')
plt.xlabel('X Axis')
plt.ylabel('Y axis')
plt.title('K-means Clustering of Wholesale Customers')
plt.legend()
plt.show()
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# Cluster centroids:
# Cluster 1: [ 1.65897027 -0.10837198 -0.21770307  1.10347289 -0.40460199  0.33302495]
# Cluster 2: [-0.49443176  0.68778461  0.91187324 -0.33156443  0.90738946  0.10242288]
# Cluster 3: [ 1.96681731  5.17550306  1.28721685  6.90059988 -0.55486198 16.47844745]
# Cluster 4: [-0.23020296 -0.38368315 -0.43654762 -0.16501283 -0.39720837 -0.19379729]
# Cluster 5: [ 3.13830315e-01  3.92190593e+00  4.27561037e+00 -3.57419457e-03
#   4.61816580e+00  5.03365339e-01]

# %%
import numpy as nm
import matplotlib.pyplot as mtp
import pandas as pd

# Load the CSV data into a DataFrame
path = "/content/Wholesale_customers_data[1].csv"
data = pd.read_csv(path)

x = data.iloc[:, [3, 4]].values  # Use 'data' instead of 'dataset'

# Finding optimal number of clusters using the elbow method
from sklearn.cluster import KMeans
wcss_list = []  # Initializing the list for the values of WCSS

# Using for loop for iterations from 1 to 10.
for i in range(1, 11):
    kmeans = KMeans(n_clusters=i, init='k-means++', random_state= 42)
    kmeans.fit(x)
    wcss_list.append(kmeans.inertia_)
mtp.plot(range(1, 11), wcss_list)
mtp.title('The Elbow Method Graph')
mtp.xlabel('Number of clusters (k)')
mtp.ylabel('WCSS (Within-Cluster Sum of Squares)')
mtp.show()

# Training the K-means model on the dataset
kmeans = KMeans(n_clusters=5, init='k-means++', random_state= 42)
y_predict = kmeans.fit_predict(x)

# Visualizing the clusters
mtp.scatter(x[y_predict == 0, 0], x[y_predict == 0, 1], s = 100, c = 'blue', label = 'Cluster 1')  # for first cluster
mtp.scatter(x[y_predict == 1, 0], x[y_predict == 1, 1], s = 100, c = 'green', label = 'Cluster 2')  # for second cluster
mtp.scatter(x[y_predict == 2, 0], x[y_predict == 2, 1], s = 100, c = 'red', label = 'Cluster 3')  # for third cluster
mtp.scatter(x[y_predict == 3, 0], x[y_predict == 3, 1], s = 100, c = 'cyan', label = 'Cluster 4')  # for fourth cluster
mtp.scatter(x[y_predict == 4, 0], x[y_predict == 4, 1], s = 100, c = 'magenta', label = 'Cluster 5')  # for fifth cluster
mtp.scatter(x[y_predict == 5, 0], x[y_predict == 5, 1], s = 100, c = 'light blue', label = 'Cluster 6')  # for first cluster
mtp.scatter(x[y_predict == 6, 0], x[y_predict == 6, 1], s = 100, c = 'dark green', label = 'Cluster 7')  # for second cluster
mtp.scatter(x[y_predict == 7, 0], x[y_predict == 7, 1], s = 100, c = 'orange', label = 'Cluster 8')  # for third cluster

mtp.scatter(kmeans.cluster_centers_[:, 0], kmeans.cluster_centers_[:, 1], s = 300, c = 'yellow', label = 'Centroid')
mtp.title('Clusters of customers')
mtp.xlabel('Annual Income (k$)')
mtp.ylabel('Spending Score (1-100)')
mtp.legend()
mtp.show()
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# ...

# %%
import numpy as nm
import matplotlib.pyplot as mtp
import pandas as pd

# Load the CSV data into a DataFrame
path = "/content/Wholesale_customers_data[1].csv"
data = pd.read_csv(path)

x = data.iloc[:, [3, 4]].values  # Use 'data' instead of 'dataset'

# Finding optimal number of clusters using the elbow method
from sklearn.cluster import KMeans
wcss_list = []  # Initializing the list for the values of WCSS

# Using for loop for iterations from 1 to 10.
for i in range(1, 11):
    kmeans = KMeans(n_clusters=i, init='k-means++', random_state= 42)
    kmeans.fit(x)
    wcss_list.append(kmeans.inertia_)
mtp.plot(range(1, 11), wcss_list)
mtp.title('The Elbow Method Graph')
mtp.xlabel('Number of clusters (k)')
mtp.ylabel('WCSS (Within-Cluster Sum of Squares)')
mtp.show()

# Training the K-means model on the dataset
kmeans = KMeans(n_clusters=8, init='k-means++', random_state= 42)
y_predict = kmeans.fit_predict(x)

# Visualizing the clusters
colors = ['blue', 'green', 'red', 'cyan', 'magenta', 'black', 'purple', 'orange']
for i in range(8):
    mtp.scatter(x[y_predict == i, 0], x[y_predict == i, 1], s = 100, c = colors[i], label = f'Cluster {i+1}')

mtp.scatter(kmeans.cluster_centers_[:, 0], kmeans.cluster_centers_[:, 1], s = 300, c = 'yellow', label = 'Centroid')
mtp.title('Clusters of customers')
mtp.xlabel('X axis')
mtp.ylabel('Y axis')
mtp.legend()
mtp.show()
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# ...
